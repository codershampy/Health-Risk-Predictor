# %%
# 1) show which Python the kernel is using
import sys
print("Python executable:", sys.executable)
print("Python version   :", sys.version)

# 2) install pandas into that same Python
# (this ensures we use the same interpreter as the kernel)
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install pandas

# 3) import and verify
import importlib
importlib.invalidate_caches()
import pandas as pd
print("pandas version:", pd.__version__)
print("pandas loaded from:", pd.__file__)
# Out:
# Python executable: c:\Users\munna\AppData\Local\Programs\Python\Python312\python.exe
# Python version   : 3.12.3 (tags/v3.12.3:f6650f9, Apr  9 2024, 14:05:25) [MSC v.1938 64 bit (AMD64)]
# ...
#   Using cached pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-25.2-py3-none-any.whl (1.8 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.0
#     Uninstalling pip-24.0:
#       Successfully uninstalled pip-24.0
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.0 MB 5.6 MB/s eta 0:00:02
#    ------ --------------------------------- 1.8/11.0 MB 5.6 MB/s eta 0:00:02
#    -------- ------------------------------- 2.4/11.0 MB 5.2 MB/s eta 0:00:02
#    ------------ --------------------------- 3.4/11.0 MB 4.5 MB/s eta 0:00:02
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\munna\Downloads\health\synthetic_health_data.csv")
df
# Out:
#       age     diet  exercise_days  sleep_hours  stress   bmi smoking alcohol  \
# 0      56     Poor              3            4    High  19.9      No    High
# 1      69  Average              2            5    High  33.9      No     Low
# 2      46  Average              7           12  Medium  31.0     Yes     Low
# 3      32     Good              1           11    High  38.1      No    High
# 4      60     Good              6           11     Low  34.6      No     Low
# ...   ...      ...            ...          ...     ...   ...     ...     ...
# 3995   35     Poor              7            7     Low  16.6      No     Low
# 3996   22  Average              6            8  Medium  38.8      No     Low
# 3997   20     Poor              5            8     Low  30.3      No  Medium
# 3998   40     Poor              2            3     Low  35.0      No     Low
# 3999   43  Average              7           11  Medium  25.2     Yes  Medium
#
#      family_history risk_level
# ...

# %%
df.shape
# Out:
# (4000, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4000 non-null   int64
#  1   diet            4000 non-null   object
#  2   exercise_days   4000 non-null   int64
#  3   sleep_hours     4000 non-null   int64
#  4   stress          4000 non-null   object
#  5   bmi             4000 non-null   float64
#  6   smoking         4000 non-null   object
#  7   alcohol         4000 non-null   object
#  8   family_history  4000 non-null   object
#  9   risk_level      4000 non-null   object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 312.6+ KB

# %%
df.isnull().sum()
# Out:
# age               0
# diet              0
# exercise_days     0
# sleep_hours       0
# stress            0
# bmi               0
# smoking           0
# alcohol           0
# family_history    0
# risk_level        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    age     diet  exercise_days  sleep_hours  stress   bmi smoking alcohol  \
# 0   56     Poor              3            4    High  19.9      No    High
# 1   69  Average              2            5    High  33.9      No     Low
# 2   46  Average              7           12  Medium  31.0     Yes     Low
# 3   32     Good              1           11    High  38.1      No    High
# 4   60     Good              6           11     Low  34.6      No     Low
#
#   family_history risk_level
# 0            Yes       High
# 1            Yes       High
# 2            Yes     Medium
# 3             No     Medium
# 4            Yes     Medium

# %%
df['age'].max()
# Out:
# np.int64(80)

# %%
df['diet'].value_counts()
# Out:
# diet
# Average    1987
# Poor       1216
# Good        797
# Name: count, dtype: int64

# %%
df['exercise_days'].max()
# Out:
# np.int64(7)

# %%
df['exercise_days'].min()
# Out:
# np.int64(0)

# %%
df['sleep_hours'].max()
# Out:
# np.int64(12)

# %%
df['sleep_hours'].min()
# Out:
# np.int64(3)

# %%
df['stress'].max()
# Out:
# 'Medium'

# %%
df['stress'].min()
# Out:
# 'High'

# %%
df['bmi'].max()
# Out:
# np.float64(40.0)

# %%
df['bmi'].min()
# Out:
# np.float64(15.0)

# %%
df['smoking'].max()
# Out:
# 'Yes'

# %%
df['smoking'].min()
# Out:
# 'No'

# %%
df['alcohol'].max()
# Out:
# 'Medium'

# %%
df['alcohol'].min()
# Out:
# 'High'

# %%
categorical_col=['diet','stress','smoking','alcohol','family_history','risk_level']

# %%
import sys

# install scikit-learn into the same environment as the kernel
# !{sys.executable} -m pip install scikit-learn

# then import
from sklearn.preprocessing import LabelEncoder
# Out:
# ...
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/8.7 MB 6.3 MB/s eta 0:00:02
#    ------ --------------------------------- 1.3/8.7 MB 5.6 MB/s eta 0:00:02
#    ------------ --------------------------- 2.6/8.7 MB 4.6 MB/s eta 0:00:02
#    -------------- ------------------------- 3.1/8.7 MB 3.8 MB/s eta 0:00:02
#    ------------------- -------------------- 4.2/8.7 MB 4.1 MB/s eta 0:00:02
#    -------------------- ------------------- 4.5/8.7 MB 3.6 MB/s eta 0:00:02
#    -------------------------- ------------- 5.8/8.7 MB 4.0 MB/s eta 0:00:01
#    ------------------------------ --------- 6.6/8.7 MB 4.0 MB/s eta 0:00:01
#    --------------------------------- ------ 7.3/8.7 MB 4.0 MB/s eta 0:00:01
#    -------------------------------------- - 8.4/8.7 MB 4.0 MB/s eta 0:00:01
# ...

# %%
encoders={}

# %%
for i in categorical_col:
    le=LabelEncoder()
    df[i]=le.fit_transform(df[i])
    encoders[i]=le

# %%
df.head()
# Out:
#    age  diet  exercise_days  sleep_hours  stress   bmi  smoking  alcohol  \
# 0   56     2              3            4       0  19.9        0        0
# 1   69     0              2            5       0  33.9        0        1
# 2   46     0              7           12       2  31.0        1        1
# 3   32     1              1           11       0  38.1        0        0
# 4   60     1              6           11       1  34.6        0        1
#
#    family_history  risk_level
# 0               1           0
# 1               1           0
# 2               1           2
# 3               0           2
# 4               1           2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4000 non-null   int64
#  1   diet            4000 non-null   int64
#  2   exercise_days   4000 non-null   int64
#  3   sleep_hours     4000 non-null   int64
#  4   stress          4000 non-null   int64
#  5   bmi             4000 non-null   float64
#  6   smoking         4000 non-null   int64
#  7   alcohol         4000 non-null   int64
#  8   family_history  4000 non-null   int64
#  9   risk_level      4000 non-null   int64
# dtypes: float64(1), int64(9)
# memory usage: 312.6 KB

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop(columns='risk_level')
y = df['risk_level']

# %%
print(x.columns)
# Out:
# Index(['age', 'diet', 'exercise_days', 'sleep_hours', 'stress', 'bmi',
#        'smoking', 'alcohol', 'family_history'],
#       dtype='object')

# %%
print(y.name)
# Out:
# risk_level

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# Create models
model = LogisticRegression()
model = RandomForestClassifier(n_estimators=100, random_state=42)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred=model.predict(x_test)

# %%
acc=accuracy_score(y_pred,y_test)

# %%
print("accuracy score of you model",acc)
# Out:
# accuracy score of you model 0.96375

# %%
#demo

# %%
df.head()
# Out:
#    age  diet  exercise_days  sleep_hours  stress   bmi  smoking  alcohol  \
# 0   56     2              3            4       0  19.9        0        0
# 1   69     0              2            5       0  33.9        0        1
# 2   46     0              7           12       2  31.0        1        1
# 3   32     1              1           11       0  38.1        0        0
# 4   60     1              6           11       1  34.6        0        1
#
#    family_history  risk_level
# 0               1           0
# 1               1           0
# 2               1           2
# 3               0           2
# 4               1           2

# %%
model.predict([[56,2,3,4,0,19.9,0,0,1]])
# Out:
# c:\Users\munna\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
 import pickle

# %%
pickle.dump(model,open("Health_risk_predict.pkl","wb"))

# %%
with open("Label_encoders.pkl","wb") as f:
    pickle.dump(encoders,f)
